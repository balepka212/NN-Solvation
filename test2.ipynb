# %%
from rdkit import Chem
from Solvation_1.Vectorizers.vectorizers import get_smiles

# %%
get_smiles('water', ('Solvation_1/Tables/get_SMILES.pkl',))
# Out:
# 'O'

# %%
file = 'Solvation_1/Tables/SMILES_solutes_all.txt'
with open(file) as f:
    for line in f:
        i, compound, smiles = line.split('\t')
        print(f'{i} -> {compound}')
        mol = Chem.MolFromSmiles(smiles)
        display(Chem.Draw.MolsToGridImage((mol,)))
# Out:
# 0 -> ethanol
# 1 -> toluene
# 2 -> 2-butanone
# 3 -> n-octane
# 4 -> nitromethane
# 5 -> 1,4-dioxane
# 6 -> phenol
# 7 -> acetic acid
# 8 -> ethyl acetate
# 9 -> butyl acetate
# 10 -> propanoic acid
# 11 -> methyl acetate
# 12 -> 1-hexanol
# 13 -> 1-propanol
# 14 -> 1-butanol
# 15 -> 1-pentanol
# 16 -> butylamine
# 17 -> propyl acetate
# 18 -> methanol
# 19 -> 1-heptanol
# 20 -> ethylamine
# 21 -> propylamine
# 22 -> methyl pentanoate
# 23 -> methyl propanoate
# 24 -> p-cresol
# 25 -> pentyl acetate
# 26 -> o-cresol
# 27 -> p-bromophenol
# 28 -> aniline
# 29 -> 2-hexanone
# 30 -> 2-pentanone
# 31 -> 2-heptanone
# 32 -> butanoic acid
# 33 -> 3,3-dimethylbutanone
# 34 -> acetone
# 35 -> methyl hexanoate
# 36 -> benzene
# 37 -> pyridine
# 38 -> m-cresol
# 39 -> water
# 40 -> diethylamine
# 41 -> hydrogen peroxide
# 42 -> pentanoic acid
# 43 -> hexanoic acid
# 44 -> 4-methylaniline
# 45 -> ethylbenzene
# 46 -> trimethylamine
# 47 -> chlorobenzene
# 48 -> acetophenone
# 49 -> methylamine
# ...

# %%
import moldesign as mdt
mol = mdt.from_name('ethylene')
mol.draw()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/16/nd0f005x4vvdmqt98d96xfv00000gn/T/ipykernel_41969/2128629022.py in <module>
# ----> 1 import moldesign as mdt
#       2 mol = mdt.from_name('ethylene')
#       3 mol.draw()
#
# ModuleNotFoundError: No module named 'moldesign'

# %%
import scipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/16/nd0f005x4vvdmqt98d96xfv00000gn/T/ipykernel_41969/2116425273.py in <module>
# ----> 1 import scipy
#
# ModuleNotFoundError: No module named 'scipy'

# %%
brew install openblas

# %%
xyz_file = '/Users/balepka/Yandex.Disk.localized/Study/Lab/Neural Network/MNSolDatabase_v2012/all_solutes/0075pro.xyz'

# %%
from rdkit.Chem import AllChem
m = Chem.MolFromSmiles(get_smiles('acetone', ('Solvation_1/Tables/get_SMILES.pkl',)))
xyz_file = '/Users/balepka/Yandex.Disk.localized/Study/Lab/Neural Network/MNSolDatabase_v2012/all_solutes/0075pro.xyz'

# this assumes whatever program you use doesn't re-order atoms
#  .. which is usually a safe assumption
#  .. so we don't bother tracking atoms
atomic_symbols = []
xyz_coordinates = []

with open(xyz_file, "r") as file:
    for line_number,line in enumerate(file):
        if line_number == 0:
            formula = line.split()[1]
            num_at = []
            for char in formula:
                if char.isnumeric():
                    num_at.append(int(char))


            num_atoms = sum(num_at)
        elif line_number == 1:
            comment1 = line # might have useful information
        elif line_number == 2:
            comment2 = line # might have useful information
        else:
            atomic_symbol, x, y, z = line.split()
            atomic_symbols.append(atomic_symbol)
            xyz_coordinates.append([float(x),float(y),float(z)])

# from https://github.com/rdkit/rdkit/issues/2413
from rdkit.Geometry import Point3D
mh=Chem.AddHs(m)
id = AllChem.EmbedMolecule(mh,useRandomCoords=True)
conf = mh.GetConformer(id)

# in principal, you should check that the atoms match
for i in range(m.GetNumAtoms()):
   x,y,z = xyz_coordinates[i]
   conf.SetAtomPosition(i,Point3D(x,y,z))

# %%
conf

# %%
from rdkit.Chem import PyMol

# %%
v = PyMol.MolViewer()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /var/folders/16/nd0f005x4vvdmqt98d96xfv00000gn/T/ipykernel_41969/4039133178.py in <module>
# ----> 1 v = PyMol.MolViewer()
#       2
#
# ~/PycharmProjects/msuAI/venv/lib/python3.8/site-packages/rdkit/Chem/PyMol.py in __init__(self, host, port, force, **kwargs)
#      35       _server = None
#      36       serv = Server('http://%s:%d' % (host, port))
# ---> 37       serv.ping()
#      38       _server = serv
#      39       self.server = serv
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/xmlrpc/client.py in __call__(self, *args)
#    1107         return _Method(self.__send, "%s.%s" % (self.__name, name))
#    1108     def __call__(self, *args):
# -> 1109         return self.__send(self.__name, args)
#    1110
#    1111 ##
#
# ...
